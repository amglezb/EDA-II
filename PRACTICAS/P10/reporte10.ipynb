# %% [markdown]
# # **Carátula**

# %%
from IPython.display import Image, display

display(Image(filename='portada_p10.jpg', width=500, height=0))

# %% [markdown]
# # **Objetivo:**
#  Conocer e identificar los aspectos sobre los archivos, como las operaciones, el tipo de
#  acceso y organización lógica.

# %% [markdown]
# # **Descripción de las actividades realizadas:**
# Simular un sistema de archivos utilizando un árbol B.
#
# A partir del programa del árbol B realizado en la práctica pasada, crear un sistema de archivos que simule la organización lógica de un Sistema Operativo
#
# El sistema de archivos debe manejar los niveles de acceso (pags. 29 y 30) y las operaciones básicas (pags. 31 y 32) que se mencionaron en la presentación del tema 5.
#
# El sistema debe cumplir con las siguientes condiciones:
#
# - Tener mínimo 10 usuarios en el sistema con diferentes niveles de acceso
# - Tener mínimo 1,000 archivos en el árbol B con diferentes niveles de acceso para las operaciones básicas
#
# Los usuarios, los permisos y la información de los archivos se deben leer de un archivo de texto plano (json, xml, csv, etc.)
#
# El programa debe permitir las siguientes funciones:
#
# - Iniciar / cerrar sesión: utilizando algún usuario válido. Se deben guardar los inicios de sesión válidos e inválidos y crear una gráfica de barras con esos datos.
# - Buscar / abrir archivo: buscar un archivo por nombre y mostrar la información del mismo con base en el nivel de acceso del usuario logeado
# - Agregar archivo: asignando los niveles de acceso que el usuario así decida
# - Listar archivos: recorrer el árbol y mostrar el nombre de los archivos a los que el usuario tenga acceso
# - Mostrar estadísticas: recorrer el árbol y mostrar una gráfica de pie con las estadísticas de los niveles de acceso del usuario para los diferentes archivos del árbol

# %% [markdown]
# # **Resultados Obtenidos**
# El código fuente y las gráficas obtenidas se encuentran en el archivo "*code.ipynb*".

# %% [markdown]
# # **Conclusiones**

# %% [markdown]
# El valor central de esta práctica reside en la implementación y la integración de estructuras de datos avanzadas y no tanto en la interfaz estática. Si bien la omisión de un menú de interacción dinámico restó facilidad de uso, el enfoque se centro en la arquitectura del backend. El código estático de prueba nos permitió validar la funcionalidad transaccional del sistema: la autenticación, la indexación, y la gestión de permisos en escenarios específicos, que era el objetivo primario. Con el uso de un arbol B la eficiencia logarítmica fue $O(\log n)$, mediante el uso del Árbol B como índice primario (p_Tree) y secundario (n_Tree) para la búsqueda de información
#
# La eficiencia de todo el sistema depende de cómo estas estructuras interactúan con la persistencia. La clase JsonController se comportó como una capa de Serialización/Persistencia, encargada de la traducción de objetos complejos a JSON y la restauración de los Árboles B en memoria al inicio. En definitiva, la práctica confirma la comprensión de que la solidez de un sistema de archivos reside en su mecanismo de indexación y tambien la compresión de las estructuras de datos no lineales como el Árbol B.
