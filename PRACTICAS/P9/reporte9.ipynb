# %% [markdown]
# # **Carátula**

# %%
from IPython.display import Image, display

display(Image(filename='portada_p9.jpg', width=500, height=0))

# %% [markdown]
# # **Objetivo:**
# Conocer e identificar las características de los árboles B.

# %% [markdown]
# # **Descripción de las actividades realizadas:**
# - **Implementar** el árbol B que viene en la presentación del tema de árboles en leguaje Python.
# - Analizar la complejidad algorítmica (dar el polinomio) para el peor caso de complejidad cuando se realiza una inserción de números de manera aleatoria de las siguientes funciones:
#     - insertNotFull
#     - splitChild
#     - traverse
#     - search
#
# de la clase **BTreeNode**
# - Generar las **gráficas** de la complejidad algloritmica de las funciones de la clase **BTreeNode** analizadas en el punto anterior.

# %% [markdown]
# # **Resultados Obtenidos**
# El código fuente y las gráficas obtenidas se encuentran en el archivo "*practica9.ipynb*".

# %% [markdown]
# # **Conclusiones**

# %% [markdown]
# En esta práctica, se implementó y analizó en detalle la estructura de datos del Árbol B, profundizando en las operaciones fundamentales de inserción, búsqueda y recorrido. El aprendizaje clave fue la comprensión de cómo la operación de división de nodos (splitChild) es el mecanismo central que garantiza el balanceo del árbol.
#
# Mediante la implementación y el análisis de complejidad (tanto teórico como empírico, contabilizando el tiempo y espacio), se comprobó que las operaciones de búsqueda e inserción alcanzan una eficiencia de $O(\log_t n)$. Esto se debe a que las operaciones se realizan en un solo paso descendente desde la raíz hasta una hoja. Por otro lado, el recorrido completo de la estructura demostró tener, como es de esperarse, una complejidad lineal $O(n)$, ya que debe visitar cada clave almacenada.
#
# En esta práctica, particularmente aprendí, como los Árboles B pueden almacenar grandes volumenes de información y todas sus operaciones se mantienen por debajo de n y las principales, como insertar y buscar son $O(\log_t n)$, por lo cual creo que son de las mejores estructuras de datos para almacenar y gestionar datos de forma masiva.
