# %% [markdown]
# # **Carátula**

# %%
from IPython.display import Image, display

display(Image(filename='portada_p8.jpg', width=500, height=0))

# %% [markdown]
# # **Objetivo:**
# Conocer e identificar las características de la estructura de datos no lineal árbol.

# %% [markdown]
# # **Descripción de las actividades realizadas:**
# - **Modelar** la clase **nodo** y la clase **árbol binario** e **implementalos** en lenguaje Python. La clase árbol binario debe tener los **métodos: insertar, buscar, elimi ar, mínimo, máximo, recorrido inorden, recorrido preorden y recorrido posorden**.
# - Obtener el **polinomio y la complejidad algorítmica** de los algoritmos de insertar, buscar, eliminar, mínimo, máximo, recorrido inorden, recorrido preorden y recorrido posorden en un árbol binario.
# - Crear las **gráficas de la complejidad** que tienen los algoritmos de insertar, buscar, eliminar, mínimo, máximo, recorrido inorden, recorrido preorden y recorrido posorden en un **árbol binario** para el peor caso de complejidad.

# %% [markdown]
# # **Resultados Obtenidos**
# El código fuente y las gráficas obtenidas se encuentran en el archivo "*practica8.ipynb*".

# %% [markdown]
# # **Conclusiones**

# %% [markdown]
# Esta práctica fue clave para consolidar mi entendimiento de los árboles binarios, llevándome desde la implementación teórica hasta el análisis práctico de su rendimiento. Al modelar las clases Nodo y Árbol Binario en Python, y al programar los recorridos recursivos (inorden, preorden, posorden), comprendí mejor la que su estructura se presta a este tipo de algoritmos. Sin embargo, mi aprendizaje más significativo provino de un error conceptual: al momento de analizar la complejidad, me centré en construir y evaluar un **árbol completamente desbalanceado**, pensando que era el peor caso, en lugar de un árbol binario. Este error fue, en realidad, muy revelador, ya que me forzó a analizar directamente el **peor caso de complejidad**. Pude confirmar que en esta estructura degenerada, similar a una lista, las operaciones de inserción, búsqueda y eliminación tienen una complejidad lineal de **$O(n)$**, en lugar del ideal logarítmico **$O(\log n)$**. Al graficar los resultados, visualicé claramente esta ineficiencia, lo que me hizo comprender de forma tangible la importancia de enteder correctamente las indicaciones para mantener el rendimiento de los árboles en aplicaciones reales y no caer en el peor escenario posible.
