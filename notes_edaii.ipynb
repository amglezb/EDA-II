# %% [markdown]
# ### **Ago-1-2025**

# %% [markdown]
# $Ω -> mejor$
#
# $o -> peor -> complejidad$

# %% [markdown]
# ## Counting Sort
# Análisis                    Temporal    Espacial
# 1. Encontrar el máximo  ->  n=len       n = len(A)
# 2. Crear el arreglo     ->  n           m = max(A)
#                             m
#                             n
#                             O(m+n)      O(m+n)
#
#                             while <- n}
#                                 while <} n + m
#
#                             graficar n, m y n + m
#
#                             Cambiar el método de comparación del nodo, Value y Name
#
#                             Análisis Temporal y espacial, solo ciclos while
# ## Radix Sort
# - Recorrer todos los elementos del conjunto empezando por el dígito menos significativo (el bit más a la derecha).
# - Hacer coincidir el dítito leído con los dígitos correspondientes en las urnas o casillas.
# - Extraer los elementos de las casillas y repetur el proceso con el siguiente dígito hasta llegar al tamaño máximo del número de dígitos.
# k = max(dig(A))
# n = len(A)
# k = dig(max(A))
# b = base(len(A))
#
# Cada letra es un ciclo de reloj.
#
# Ordenamientos externos
# Cuando el conjunto de datos que se desea clasifcicar es mayor a la capacidad de almacenamiento primaria y, por ende, los datos se encuentran alamcenados
#
# Método por Polifase
# RAM tiempo en nanosegundos
# DD tiempo en milisegundos
#
# mockaroo.com
# leet ode

# %% [markdown]
# # **2. Algortimos de búsqueda**

# %% [markdown]
# ## Búsquedas
# ### Búsqueda x transformación de llaves
# - Funciones de Hash
# - Colisiones
# ### Búsqueda x comparación de llaves
# - Búsqueda Lineal (Sencilla)
#     - Mejor Caso (Que se encuentre en la primera posición $O(1)$)
#     - Peor Caso (No está o esta en la última posición $O(n)$)
#     - Promedio (Oscila entre los 2 casos)
# - Búsqueda Binaria
#     - Restricción: Lista Ordenada
#     - Complejidad n, 1 + Complejidad del Ordenamiento

# %% [markdown]
# ### Práctica 4
# - Implementar Búsqueda Lineal y Binaria
# - Algoritmos Iterativo y Recursivo
# - Gráficas
#     - Lineal Iterativa
#         - Mejor
#         - Peor
#         - Promedio
#         - Comparativa
#
#     - Lineal Recursiva
#         - Mejor
#         - Peor
#         - Promedio
#         - Comparativa
#
#     - Binaria Iterativa
#         - Eficiente
#             - Mejor
#             - Peor
#             - Promedio
#             - Comparativa
#         - Ineficiente
#             - Mejor
#             - Peor
#             - Promedio
#             - Comparativa
#
#     - Binaria Recursiva
#         - Eficiente
#             - Mejor
#             - Peor
#             - Promedio
#             - Comparativa
#         - Ineficiente
#             - Mejor
#             - Peor
#             - Promedio
#             - Comparativa
#     - 24 en total

# %% [markdown]
# ## Sep-03-2025
# Función Hash -> Suficientemente dispersa
#
# Búsqueda por transformación de llaves
#
# $hash(key)<-[0,n-1]$
#
# $return key mod n$
#
# key->[n()]->dir
#
# colision
# - Recorrer todo -> Reasignación
# - Arreglos Anidados
# - Encadenamiento
#
#
# Primer examen: Función Hash Criptográfica -> Menor número de colisiones, no por repeticion
#
#
#
# (Graficar Complejidad Espacial y Temporal $(n,k, n+k)$, Separadas, la asignación utiliza 2 espacios, while usa un espacio, llamada a función 1 espacio), Radix es en función de 3 variables

# %% [markdown]
# - Temporal
#     - Time
#     - n
#     - k
#     - n+k
#     - comparativa
# - Espacial
#     - Space
#     - n
#     - k
#     - n+k
#     - comparativa

# %% [markdown]
# ## **Clases de Complejidad**
#
# - P -> Polinomial, Determinista -> Que pueden ser ejecutados en un tiempo polinomial en una máquina de Turing, una entrada la misma salida
# - NP -> No deerminista, polinomial -> Una entrada diferentes salidas, no se realiza en un tiempo polinomial pero si comprobar
# - NPC -> $Sat<=_p3Sat$
# - NP Hard -> Muy Difícil

# %% [markdown]
# ## **Estrucuras de Datos no Lineales**
# - **Grafo**
# $G = {v, a}$ -> conjunto de vertices y aristas
#
# $V(G)$ -> O
#
# $A(G)$ -> |
#
# Cada arista solo puede unir un par de nodos -> $a(u, v)$
#
# $A={n_1, n_2, n_3, ...}$
#
# $AXA={(n_1,n_1),(n_1,n_2),(n_1,n_3)}$
#
# $G C= A X A$
#
# grado de un nodo = # aristas
#
# nodo que apunta a sí mismo, tiene nombre de lazo -> $a(u, u)$
#
# Path -> Secuencia/Conjunto de vertices finito, que se debe recorrer para llegar del vertice 1 al vertice n
#
# Close Path -> Vertice inicial y vertice final son iguales
#
# Grado Conexo -> E camino simple para cualesquiera 2 de sus nodos
#
# Grafo completo -> Todos sus nodos están conectados con todos los demás
#
# Grafos -> n=#vertices,m=#aristas $=n(n-1)/2=(n^2-n)/2$
#
# Grafo Etiquetado -> Con costos, peso, distancia
#
# Grafo dirigido -> Flechas 1 dirección -> Digraf
#
# - Grafo Interno: LLega al nodo -> Horizontal
# - Grafo Externo: Sale del nodo -> Vertical
#
# ## **En la computadora**
#     - Matriz de Adyacencia n*n
#     - Lista de adyacencia n+m
#     - Lista de aristas
#
# - **Arbol**
#
# Grafo conexa sin ciclos
